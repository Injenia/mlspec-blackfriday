# %%
import os
import numpy as np
import pandas as pd

# %%
BASE_DATASET = "../../data/mlspec-blackfriday/dataset/raw"
os.makedirs(BASE_DATASET, exist_ok=True)

# %%
# !gsutil cp -r gs://mlteam-ml-specialization-2021-blackfriday/dataset/raw/* $BASE_DATASET/
# Out:
# Copying gs://mlteam-ml-specialization-2021-blackfriday/dataset/raw/README.md...
# Copying gs://mlteam-ml-specialization-2021-blackfriday/dataset/raw/test.csv...
# Copying gs://mlteam-ml-specialization-2021-blackfriday/dataset/raw/train.csv...
#
# Operation completed over 3 objects/33.5 MiB.

# %%
TRAIN_SET = os.path.join(BASE_DATASET, 'train.csv')
df = pd.read_csv(TRAIN_SET)

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
PRODUCT_COLUMNS = [
    'Product_ID', 'Product_Category_1',
    'Product_Category_2', 'Product_Category_3'
]

df_totals = df.groupby(PRODUCT_COLUMNS).agg(
    {
        'User_ID': 'count',
        'Purchase': ['count', 'sum', 'min', 'mean', 'max', 'std']
    }
)
df_totals.columns = ['_'.join(col) for col in df_totals.columns.values]
df_totals = df_totals.reset_index()

# %%
# Display the Dive visualization for the training data.
from IPython.core.display import display, HTML

jsonstr = df_totals.to_json(orient='records')
HTML_TEMPLATE = """
        <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
        <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
        <facets-dive id="elem" height="600"></facets-dive>
        <script>
          var data = {jsonstr};
          document.querySelector("#elem").data = data;
        </script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#         <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#         <facets-dive id="elem" height="600"></facets-dive>
#         <script>
#           var data = [{"Product_ID":"P00000142","Product_Category_1":3,"Product_Category_2":4.0,"Product_Category_3":5.0,"User_ID_count":1152,"Purchase_count":1152,"Purchase_sum":12837476,"Purchase_min":2725,"Purchase_mean":11143.6423611111,"Purchase_max":13716,"Purchase_std":2305.1752610289},{"Product_ID":"P00000242","Product_Category_1":2,"Product_Category_2":4.0,"Product_Category_3":9.0,"User_ID_count":376,"Purchase_count":376,"Purchase_sum":3967496,"Purchase_min":3214,"Purchase_mean":10551.8510638298,"Purchase_max":16503,"Purchase_std":3170.6034166636},{"Product_ID":"P00000642","Product_Category_1":1,"Product_Category_2":6.0,"Product_Category_3":16.0,"User_ID_count":512,"Purchase_count":512,"Purchase_sum":7635578,"Purchase_min":3950,"Purchase_mean":14913.23828125,"Purchase_max":19705,"Purchase_std":3633.14252036},{"Product_ID":"P00001042","Product_Category_1":1,"Product_Category_2":2.0,"Product_Category_3":16.0,"User_ID_count":503,"Purchase_count":503,"Purchase_sum":6922380,"Purchase_min":3847,"Purchase_mean":13762.1868787276,"Purchase_max":19670,"Purchase_std":3377.132740459},{"Product_ID":"P00001